# %%
import arcticdb as adb
import dotenv
import pandas as pd
from eodhd import APIClient
import os

dotenv.load_dotenv(dotenv_path="../.env")

# %%
ac = adb.Arctic('lmdb://../data_storage/database')
# ac.create_library('data')  # fixed schema - see note below
ac.list_libraries()
library = ac['data']

# %%
api_key = os.environ.get("EODHD_API_KEY")
api = APIClient(api_key)

# %%
exchange_df = api.get_exchanges()

# %%
tradeable_exchanges = [
    'NASDAQ',
    'NYSE',
    'NYSE MKT',
    'NYSE ARCA',
    'NYSEARCA',
    'BATS',
    'AMEX'
]

# %%
symbols = api.get_exchange_symbols(uri='US')

# %%
active_stocks = symbols[symbols['Exchange'].isin(tradeable_exchanges) & (symbols['Type'] == 'Common Stock')]

# %%
active_stocks['Code'][0:100]
# Out:
# 4          A
# 5         AA
# 53      AACG
# 56      AACI
# 58     AACIW
#        ...
# 710      ADC
# 717     ADCT
# 721      ADD
# 728     ADEA
# 733     ADEX
# Name: Code, Length: 100, dtype: object

# %%
for code in active_stocks['Code'][0:10].tolist():
    test = api.get_fundamentals_data(ticker=f'{code}.US')

# %%
delisted_symbols = api.get_exchange_symbols(uri='US', delisted=True)

# %%
delisted_stocks = delisted_symbols[delisted_symbols['Exchange'].isin(tradeable_exchanges) & (delisted_symbols['Type'] == 'Common Stock')]

# %%
delisted_stocks
# Out:
#          Code                                    Name Country Exchange  \
# 0        AAAB                   Admiralty Bancorp Inc     USA   NASDAQ
# 2       AAAGY               Altana Aktiengesellschaft     USA     NYSE
# 6        AAAP   Advanced Accelerator Applications S.A     USA   NASDAQ
# 9         AAB                          Astrazeneca Ab     USA     NYSE
# 10       AABA                              Altaba Inc     USA   NASDAQ
# ...       ...                                     ...     ...      ...
# 47489      ZX  China Zenix Auto International Limited     USA     NYSE
# 47491  ZXYZ-A                   NASDAQ SYMBOLOGY TEST     USA   NASDAQ
# 47492      ZY                            Zymergen Inc     USA   NASDAQ
# 47494    ZYNE             Zynerba Pharmaceuticals Inc     USA   NASDAQ
# 47498      ZZ                              Sealy Corp     USA     NYSE
#
#       Currency          Type          Isin
# 0          USD  Common Stock          None
# 2          USD  Common Stock          None
# 6          USD  Common Stock  US00790T1007
# 9          USD  Common Stock          None
# 10         USD  Common Stock  US0213461017
# ...        ...           ...           ...
# 47489      USD  Common Stock  US16951E1047
# 47491      USD  Common Stock          None
# 47492      USD  Common Stock  US98985X1000
# 47494      USD  Common Stock  US98986X1090
# 47498      USD  Common Stock          None
#
# [14672 rows x 7 columns]

# %%
fundamental_data = api.get_fundamentals_data(ticker='ABCM.US')

# %%
income_statement_df = pd.DataFrame(fundamental_data['Financials']['Income_Statement']['quarterly']).transpose()

# %%
income_statement_df = (income_statement_df
                       .reset_index(drop=True)
                       .astype()
                       )

# %%
date_fields = ['date', 'filing_date']
string_field = ['currency_symbol']
float_field_mask = ~income_statement_df.columns.isin(date_fields + string_field)
float_column_names = income_statement_df.columns[float_field_mask]

# %%
income_statement_df[date_fields] = income_statement_df[date_fields].apply(pd.to_datetime)
income_statement_df[string_field] = income_statement_df[string_field].astype(str)
income_statement_df[float_column_names] = income_statement_df[float_column_names].astype(float)

# %%
income_statement_df
# Out:
#           date filing_date currency_symbol  researchDevelopment  \
# 0   2024-03-31  2024-05-03             USD  7903000000.00000000
# 1   2023-12-31  2024-02-02             USD  7696000000.00000000
# 2   2023-09-30  2023-11-03             USD  7307000000.00000000
# 3   2023-06-30  2023-08-04             USD  7442000000.00000000
# 4   2023-03-31  2023-05-05             USD  7457000000.00000000
# ..         ...         ...             ...                  ...
# 150 1986-09-30  1986-09-30             USD                  NaN
# 151 1986-06-30  1986-06-30             USD                  NaN
# 152 1986-03-31  1986-03-31             USD                  NaN
# 153 1985-12-31  1985-12-31             USD                  NaN
# 154 1985-09-30  1985-09-30             USD                  NaN
#
#      effectOfAccountingCharges      incomeBeforeTax  minorityInterest  \
# 0                          NaN 28058000000.00000000               NaN
# 1                          NaN 40323000000.00000000               NaN
# 2                          NaN 26998000000.00000000               NaN
# 3                          NaN 22733000000.00000000               NaN
# 4                          NaN 28382000000.00000000               NaN
# ..                         ...                  ...               ...
# 150                        NaN                  NaN               NaN
# 151                        NaN                  NaN               NaN
# 152                        NaN                  NaN               NaN
# 153                        NaN                  NaN               NaN
# 154                        NaN                  NaN               NaN
#
#                netIncome  sellingGeneralAdministrative  \
# 0   23636000000.00000000           6468000000.00000000
# 1   33916000000.00000000           6786000000.00000000
# 2   22956000000.00000000           6151000000.00000000
# 3   19881000000.00000000           5973000000.00000000
# 4   24160000000.00000000           6201000000.00000000
# ..                   ...                           ...
# 150                  NaN                           NaN
# 151                  NaN                           NaN
# 152                  NaN                           NaN
# 153                  NaN                           NaN
# 154                  NaN                           NaN
#
#      sellingAndMarketingExpenses  ...  otherItems    incomeTaxExpense  \
# 0                            NaN  ...         NaN 4422000000.00000000
# 1                            NaN  ...         NaN 6407000000.00000000
# 2                            NaN  ...         NaN 4042000000.00000000
# 3                            NaN  ...         NaN 2852000000.00000000
# 4                            NaN  ...         NaN 4222000000.00000000
# ..                           ...  ...         ...                 ...
# 150                          NaN  ...         NaN                 NaN
# 151                          NaN  ...         NaN                 NaN
# 152                          NaN  ...         NaN                 NaN
# 153                          NaN  ...         NaN                 NaN
# 154                          NaN  ...         NaN                 NaN
#
#              totalRevenue  totalOperatingExpenses        costOfRevenue  \
# 0    90753000000.00000000    14371000000.00000000 48482000000.00000000
# 1   119575000000.00000000    14482000000.00000000 64720000000.00000000
# 2    89498000000.00000000    13458000000.00000000 49071000000.00000000
# 3    81797000000.00000000    13415000000.00000000 45384000000.00000000
# 4    94836000000.00000000    13658000000.00000000 52860000000.00000000
# ..                    ...                     ...                  ...
# 150    510800000.00000000    -1628400000.00000000                  NaN
# 151    448300000.00000000                     NaN                  NaN
# 152    408900000.00000000                     NaN                  NaN
# 153    533900000.00000000                     NaN                  NaN
# 154    409700000.00000000    -1771000000.00000000                  NaN
#
#      totalOtherIncomeExpenseNet  discontinuedOperations  \
# 0            158000000.00000000                     NaN
# 1            -50000000.00000000                     NaN
# 2             29000000.00000000                     NaN
# 3           -265000000.00000000                     NaN
# 4             64000000.00000000                     NaN
# ..                          ...                     ...
# 150                         NaN                     NaN
# 151                         NaN                     NaN
# 152                         NaN                     NaN
# 153                         NaN                     NaN
# 154                         NaN                     NaN
#
#      netIncomeFromContinuingOps  netIncomeApplicableToCommonShares  \
# 0          23636000000.00000000                                NaN
# 1          33916000000.00000000                                NaN
# 2          22956000000.00000000               22956000000.00000000
# 3          19881000000.00000000               19881000000.00000000
# 4          24160000000.00000000               24160000000.00000000
# ..                          ...                                ...
# 150                         NaN                                NaN
# 151                         NaN                                NaN
# 152                         NaN                                NaN
# 153                         NaN                                NaN
# 154                         NaN                                NaN
#
#      preferredStockAndOtherAdjustments
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 150                                NaN
# 151                                NaN
# 152                                NaN
# 153                                NaN
# 154                                NaN
#
# [155 rows x 34 columns]

# %%
library.write('income_statement', income_statement_df)
# Out:
# VersionedItem(symbol='income_statement', library='data', data=n/a, version=0, metadata=None, host='LMDB(path=C:\\Users\\mason\\PycharmProjects\\quantitative-finance\\data_storage\\database)', timestamp=1721181452715667400)

# %%
from_storage_df = library.read('income_statement').data

# %%
from_storage_df
# Out:
#           date filing_date currency_symbol  researchDevelopment  \
# 0   2024-03-31  2024-05-03             USD  7903000000.00000000
# 1   2023-12-31  2024-02-02             USD  7696000000.00000000
# 2   2023-09-30  2023-11-03             USD  7307000000.00000000
# 3   2023-06-30  2023-08-04             USD  7442000000.00000000
# 4   2023-03-31  2023-05-05             USD  7457000000.00000000
# ..         ...         ...             ...                  ...
# 150 1986-09-30  1986-09-30             USD                  NaN
# 151 1986-06-30  1986-06-30             USD                  NaN
# 152 1986-03-31  1986-03-31             USD                  NaN
# 153 1985-12-31  1985-12-31             USD                  NaN
# 154 1985-09-30  1985-09-30             USD                  NaN
#
#      effectOfAccountingCharges      incomeBeforeTax  minorityInterest  \
# 0                          NaN 28058000000.00000000               NaN
# 1                          NaN 40323000000.00000000               NaN
# 2                          NaN 26998000000.00000000               NaN
# 3                          NaN 22733000000.00000000               NaN
# 4                          NaN 28382000000.00000000               NaN
# ..                         ...                  ...               ...
# 150                        NaN                  NaN               NaN
# 151                        NaN                  NaN               NaN
# 152                        NaN                  NaN               NaN
# 153                        NaN                  NaN               NaN
# 154                        NaN                  NaN               NaN
#
#                netIncome  sellingGeneralAdministrative  \
# 0   23636000000.00000000           6468000000.00000000
# 1   33916000000.00000000           6786000000.00000000
# 2   22956000000.00000000           6151000000.00000000
# 3   19881000000.00000000           5973000000.00000000
# 4   24160000000.00000000           6201000000.00000000
# ..                   ...                           ...
# 150                  NaN                           NaN
# 151                  NaN                           NaN
# 152                  NaN                           NaN
# 153                  NaN                           NaN
# 154                  NaN                           NaN
#
#      sellingAndMarketingExpenses  ...  otherItems    incomeTaxExpense  \
# 0                            NaN  ...         NaN 4422000000.00000000
# 1                            NaN  ...         NaN 6407000000.00000000
# 2                            NaN  ...         NaN 4042000000.00000000
# 3                            NaN  ...         NaN 2852000000.00000000
# 4                            NaN  ...         NaN 4222000000.00000000
# ..                           ...  ...         ...                 ...
# 150                          NaN  ...         NaN                 NaN
# 151                          NaN  ...         NaN                 NaN
# 152                          NaN  ...         NaN                 NaN
# 153                          NaN  ...         NaN                 NaN
# 154                          NaN  ...         NaN                 NaN
#
#              totalRevenue  totalOperatingExpenses        costOfRevenue  \
# 0    90753000000.00000000    14371000000.00000000 48482000000.00000000
# 1   119575000000.00000000    14482000000.00000000 64720000000.00000000
# 2    89498000000.00000000    13458000000.00000000 49071000000.00000000
# 3    81797000000.00000000    13415000000.00000000 45384000000.00000000
# 4    94836000000.00000000    13658000000.00000000 52860000000.00000000
# ..                    ...                     ...                  ...
# 150    510800000.00000000    -1628400000.00000000                  NaN
# 151    448300000.00000000                     NaN                  NaN
# 152    408900000.00000000                     NaN                  NaN
# 153    533900000.00000000                     NaN                  NaN
# 154    409700000.00000000    -1771000000.00000000                  NaN
#
#      totalOtherIncomeExpenseNet  discontinuedOperations  \
# 0            158000000.00000000                     NaN
# 1            -50000000.00000000                     NaN
# 2             29000000.00000000                     NaN
# 3           -265000000.00000000                     NaN
# 4             64000000.00000000                     NaN
# ..                          ...                     ...
# 150                         NaN                     NaN
# 151                         NaN                     NaN
# 152                         NaN                     NaN
# 153                         NaN                     NaN
# 154                         NaN                     NaN
#
#      netIncomeFromContinuingOps  netIncomeApplicableToCommonShares  \
# 0          23636000000.00000000                                NaN
# 1          33916000000.00000000                                NaN
# 2          22956000000.00000000               22956000000.00000000
# 3          19881000000.00000000               19881000000.00000000
# 4          24160000000.00000000               24160000000.00000000
# ..                          ...                                ...
# 150                         NaN                                NaN
# 151                         NaN                                NaN
# 152                         NaN                                NaN
# 153                         NaN                                NaN
# 154                         NaN                                NaN
#
#      preferredStockAndOtherAdjustments
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 150                                NaN
# 151                                NaN
# 152                                NaN
# 153                                NaN
# 154                                NaN
#
# [155 rows x 34 columns]
